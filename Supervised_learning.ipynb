# %% [markdown]
# # Import packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load the dataset

# %%
data = pd.read_csv("Loan_default.csv")

# %%
data.head()
# Out:
#        LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 0  I38PQUQS96   56   85994       50587          520              80
# 1  HPSK72WA7R   69   50432      124440          458              15
# 2  C1OZ6DPJ8Y   46   84208      129188          451              26
# 3  V2KKSFM3UN   32   31713       44799          743               0
# 4  EY08JDHTZP   60   20437        9139          633               8
#
#    NumCreditLines  InterestRate  LoanTerm  DTIRatio    Education  \
# 0               4         15.23        36      0.44   Bachelor's
# 1               1          4.81        60      0.68     Master's
# 2               3         21.17        24      0.31     Master's
# 3               3          7.07        24      0.23  High School
# 4               4          6.51        48      0.73   Bachelor's
#
#   EmploymentType MaritalStatus HasMortgage HasDependents LoanPurpose  \
# 0      Full-time      Divorced         Yes           Yes       Other
# 1      Full-time       Married          No            No       Other
# 2     Unemployed      Divorced         Yes           Yes        Auto
# 3      Full-time       Married          No            No    Business
# 4     Unemployed      Divorced          No           Yes        Auto
#
#   HasCoSigner  Default
# 0         Yes        0
# 1         Yes        0
# 2          No        1
# 3          No        0
# 4          No        0

# %%
data.describe().T
# Out:
#                    count           mean           std      min       25%  \
# Age             255347.0      43.498306     14.990258     18.0     31.00
# Income          255347.0   82499.304597  38963.013729  15000.0  48825.50
# LoanAmount      255347.0  127578.865512  70840.706142   5000.0  66156.00
# CreditScore     255347.0     574.264346    158.903867    300.0    437.00
# MonthsEmployed  255347.0      59.541976     34.643376      0.0     30.00
# NumCreditLines  255347.0       2.501036      1.117018      1.0      2.00
# InterestRate    255347.0      13.492773      6.636443      2.0      7.77
# LoanTerm        255347.0      36.025894     16.969330     12.0     24.00
# DTIRatio        255347.0       0.500212      0.230917      0.1      0.30
# Default         255347.0       0.116128      0.320379      0.0      0.00
#
#                       50%        75%       max
# Age                 43.00      56.00      69.0
# Income           82466.00  116219.00  149999.0
# LoanAmount      127556.00  188985.00  249999.0
# CreditScore        574.00     712.00     849.0
# MonthsEmployed      60.00      90.00     119.0
# NumCreditLines       2.00       3.00       4.0
# InterestRate        13.46      19.25      25.0
# LoanTerm            36.00      48.00      60.0
# DTIRatio             0.50       0.70       0.9
# Default              0.00       0.00       1.0

# %%
data.dtypes
# Out:
# LoanID             object
# Age                 int64
# Income              int64
# LoanAmount          int64
# CreditScore         int64
# MonthsEmployed      int64
# NumCreditLines      int64
# InterestRate      float64
# LoanTerm            int64
# DTIRatio          float64
# Education          object
# EmploymentType     object
# MaritalStatus      object
# HasMortgage        object
# HasDependents      object
# LoanPurpose        object
# HasCoSigner        object
# Default             int64
# dtype: object

# %%
data.isnull().sum()
# Out:
# LoanID            0
# Age               0
# Income            0
# LoanAmount        0
# CreditScore       0
# MonthsEmployed    0
# NumCreditLines    0
# InterestRate      0
# LoanTerm          0
# DTIRatio          0
# Education         0
# EmploymentType    0
# MaritalStatus     0
# HasMortgage       0
# HasDependents     0
# LoanPurpose       0
# HasCoSigner       0
# Default           0
# dtype: int64

# %%
data.isnull()
# Out:
#         LoanID    Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 0        False  False   False       False        False           False
# 1        False  False   False       False        False           False
# 2        False  False   False       False        False           False
# 3        False  False   False       False        False           False
# 4        False  False   False       False        False           False
# ...        ...    ...     ...         ...          ...             ...
# 255342   False  False   False       False        False           False
# 255343   False  False   False       False        False           False
# 255344   False  False   False       False        False           False
# 255345   False  False   False       False        False           False
# 255346   False  False   False       False        False           False
#
#         NumCreditLines  InterestRate  LoanTerm  DTIRatio  Education  \
# 0                False         False     False     False      False
# 1                False         False     False     False      False
# 2                False         False     False     False      False
# 3                False         False     False     False      False
# 4                False         False     False     False      False
# ...                ...           ...       ...       ...        ...
# 255342           False         False     False     False      False
# 255343           False         False     False     False      False
# 255344           False         False     False     False      False
# 255345           False         False     False     False      False
# 255346           False         False     False     False      False
#
#         EmploymentType  MaritalStatus  HasMortgage  HasDependents  \
# 0                False          False        False          False
# 1                False          False        False          False
# 2                False          False        False          False
# 3                False          False        False          False
# 4                False          False        False          False
# ...                ...            ...          ...            ...
# 255342           False          False        False          False
# 255343           False          False        False          False
# 255344           False          False        False          False
# 255345           False          False        False          False
# 255346           False          False        False          False
#
#         LoanPurpose  HasCoSigner  Default
# 0             False        False    False
# 1             False        False    False
# 2             False        False    False
# 3             False        False    False
# 4             False        False    False
# ...             ...          ...      ...
# 255342        False        False    False
# 255343        False        False    False
# 255344        False        False    False
# 255345        False        False    False
# 255346        False        False    False
#
# [255347 rows x 18 columns]

# %%
plt.figure(figsize  =(10,5))
sns.heatmap(data = data.isnull(), cmap = "viridis", vmin = 0, vmax =1)
plt.xticks(rotation = 45)
plt.show();

# %%
# drop irrelevant columns

data = data.drop(["LoanID"], axis =1)

# %%
data.head(2)
# Out:
#    Age  Income  LoanAmount  CreditScore  MonthsEmployed  NumCreditLines  \
# 0   56   85994       50587          520              80               4
# 1   69   50432      124440          458              15               1
#
#    InterestRate  LoanTerm  DTIRatio   Education EmploymentType MaritalStatus  \
# 0         15.23        36      0.44  Bachelor's      Full-time      Divorced
# 1          4.81        60      0.68    Master's      Full-time       Married
#
#   HasMortgage HasDependents LoanPurpose HasCoSigner  Default
# 0         Yes           Yes       Other         Yes        0
# 1          No            No       Other         Yes        0

# %% [markdown]
# # Numerical data

# %%
numerical_df = data.select_dtypes(exclude = "object")

# %%
numerical_df.head()
# Out:
#    Age  Income  LoanAmount  CreditScore  MonthsEmployed  NumCreditLines  \
# 0   56   85994       50587          520              80               4
# 1   69   50432      124440          458              15               1
# 2   46   84208      129188          451              26               3
# 3   32   31713       44799          743               0               3
# 4   60   20437        9139          633               8               4
#
#    InterestRate  LoanTerm  DTIRatio  Default
# 0         15.23        36      0.44        0
# 1          4.81        60      0.68        0
# 2         21.17        24      0.31        1
# 3          7.07        24      0.23        0
# 4          6.51        48      0.73        0

# %% [markdown]
# ### Univariate analysis

# %%
plt.figure(figsize = (10 ,5 ))
sns.histplot(data = data["Age"], bins = 100)
plt.title("Distribution of Age")
plt.ylabel("Frequency")
plt.show()
# Out:
# c:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize = (6,3))
sns.boxplot(data = data["Age"], orient = 'h', color = "orange")
plt.title("Box plot for age")
plt.xlabel("Age")
# Out:
# Text(0.5, 0, 'Age')

# %%
fig, position = plt.subplots(nrows= 1, ncols= 2, figsize = (10,5))

sns.histplot(data = data["Age"], bins =4, ax = position[0])
position[0].set_title("Histogram of Age")

sns.boxplot(data = data["Age"], orient = "h", color = "orange", ax = position[1])
position[1].set_title("Boxplot of Age")
# Out:
# c:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'Boxplot of Age')

# %%
fig, axes = plt.subplots(nrows= 2, ncols= 2, figsize = (10,5))

sns.histplot(data= data["Age"], bins =4, ax = axes[0,1])
axes[0,1].set_title("Histogram of Age")

sns.boxplot(data = data["Age"], orient = 'h',color = "orange", ax = axes[1,0])
axes[1,0].set_title("Box plot for Age")
# Out:
# c:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'Box plot for Age')

# %%
numerical_df.head(2)
# Out:
#    Age  Income  LoanAmount  CreditScore  MonthsEmployed  NumCreditLines  \
# 0   56   85994       50587          520              80               4
# 1   69   50432      124440          458              15               1
#
#    InterestRate  LoanTerm  DTIRatio  Default
# 0         15.23        36      0.44        0
# 1          4.81        60      0.68        0

# %% [markdown]
# **Distibution of Numerical features**

# %%
numerical_cols = numerical_df.columns.to_list()

# %%
my_list = ["precious", "adam", "eve", "jacob"]

for index,name in enumerate(my_list):
    print(name)
    print(index)
# Out:
# precious
# 0
# adam
# 1
# eve
# 2
# jacob
# 3

# %%
def random_function():
    hdskdwjshds
    
    
    return x, y

# %%
numerical_cols
# Out:
# ['Age',
#  'Income',
#  'LoanAmount',
#  'CreditScore',
#  'MonthsEmployed',
#  'NumCreditLines',
#  'InterestRate',
#  'LoanTerm',
#  'DTIRatio',
#  'Default']

# %%
n_features  =len(numerical_cols)
num_cols = 2
num_rows = (n_features + 1)//num_cols

fig, axes = plt.subplots(ncols= num_cols, nrows = num_rows, figsize = (20,10))

position  = axes.flatten()

for index, name_of_feature in enumerate(numerical_cols):
    sns.boxplot(data = data[name_of_feature], ax = position[index], orient = "h", color = "orange")
    
plt.tight_layout()

# %%
n_features  =len(numerical_cols)
num_cols = 2
num_rows = (n_features + 1)//num_cols

fig, axes = plt.subplots(ncols= num_cols, nrows = num_rows, figsize = (20,20))

position  = axes.flatten()

for index, name_of_feature in enumerate(numerical_cols):
    sns.histplot(data = data[name_of_feature], ax = position[index])
    
plt.tight_layout()
# Out:
# c:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### Bivairate analysis

# %%
numerical_df.corr()
# Out:
#                      Age    Income  LoanAmount  CreditScore  MonthsEmployed  \
# Age             1.000000 -0.001244   -0.002213    -0.000548       -0.000341
# Income         -0.001244  1.000000   -0.000865    -0.001430        0.002675
# LoanAmount     -0.002213 -0.000865    1.000000     0.001261        0.002817
# CreditScore    -0.000548 -0.001430    0.001261     1.000000        0.000613
# MonthsEmployed -0.000341  0.002675    0.002817     0.000613        1.000000
# NumCreditLines -0.000890 -0.002016    0.000794     0.000016        0.001267
# InterestRate   -0.001127 -0.002303   -0.002291     0.000436        0.000096
# LoanTerm        0.000263 -0.000998    0.002538     0.001130       -0.001166
# DTIRatio       -0.004689  0.000205    0.001122    -0.001039        0.001765
# Default        -0.167783 -0.099119    0.086659    -0.034166       -0.097374
#
#                 NumCreditLines  InterestRate  LoanTerm  DTIRatio   Default
# Age                  -0.000890     -0.001127  0.000263 -0.004689 -0.167783
# Income               -0.002016     -0.002303 -0.000998  0.000205 -0.099119
# LoanAmount            0.000794     -0.002291  0.002538  0.001122  0.086659
# CreditScore           0.000016      0.000436  0.001130 -0.001039 -0.034166
# MonthsEmployed        0.001267      0.000096 -0.001166  0.001765 -0.097374
# NumCreditLines        1.000000     -0.000297 -0.000226 -0.000586  0.028330
# InterestRate         -0.000297      1.000000  0.000892  0.000575  0.131273
# LoanTerm             -0.000226      0.000892  1.000000  0.002273  0.000545
# DTIRatio             -0.000586      0.000575  0.002273  1.000000  0.019236
# Default               0.028330      0.131273  0.000545  0.019236  1.000000

# %%
plt.figure(figsize = (13,6))
sns.heatmap(data=numerical_df.corr(), cmap = "viridis", annot=True, fmt=".2f")
# Out:
# <Axes: >

# %% [markdown]
# # Categorical data

# %%
categorical_df = data.select_dtypes(include = "object")

# %%
categorical_df.head(2)
# Out:
#     Education EmploymentType MaritalStatus HasMortgage HasDependents  \
# 0  Bachelor's      Full-time      Divorced         Yes           Yes
# 1    Master's      Full-time       Married          No            No
#
#   LoanPurpose HasCoSigner
# 0       Other         Yes
# 1       Other         Yes

# %%
cat_columns = categorical_df.columns.to_list()
cat_columns
# Out:
# ['Education',
#  'EmploymentType',
#  'MaritalStatus',
#  'HasMortgage',
#  'HasDependents',
#  'LoanPurpose',
#  'HasCoSigner']

# %%
for feature in cat_columns:
    print(f"{feature} -----------> {data[feature].nunique()}")
# Out:
# Education -----------> 4
# EmploymentType -----------> 4
# MaritalStatus -----------> 3
# HasMortgage -----------> 2
# HasDependents -----------> 2
# LoanPurpose -----------> 5
# HasCoSigner -----------> 2

# %% [markdown]
# ### Univariate analysis

# %%
education_count = data["Education"].value_counts()
education_count
# Out:
# Education
# Bachelor's     64366
# High School    63903
# Master's       63541
# PhD            63537
# Name: count, dtype: int64

# %%
education_count.index
# Out:
# Index(['Bachelor's', 'High School', 'Master's', 'PhD'], dtype='object', name='Education')

# %%
sns.barplot(x = education_count.index , y = education_count.values)
# Out:
# <Axes: xlabel='Education'>

# %%
categorical_df.head()
# Out:
#      Education EmploymentType MaritalStatus HasMortgage HasDependents  \
# 0   Bachelor's      Full-time      Divorced         Yes           Yes
# 1     Master's      Full-time       Married          No            No
# 2     Master's     Unemployed      Divorced         Yes           Yes
# 3  High School      Full-time       Married          No            No
# 4   Bachelor's     Unemployed      Divorced          No           Yes
#
#   LoanPurpose HasCoSigner
# 0       Other         Yes
# 1       Other         Yes
# 2        Auto          No
# 3    Business          No
# 4        Auto          No

# %%
cat_columns
# Out:
# ['Education',
#  'EmploymentType',
#  'MaritalStatus',
#  'HasMortgage',
#  'HasDependents',
#  'LoanPurpose',
#  'HasCoSigner']

# %%
fig, axes = plt.subplots(nrows= 4, ncols= 2, figsize = (20,20))

position = axes.flatten()

for index, feature in enumerate(cat_columns):
    sns.barplot(x = data[feature].value_counts().index, y = data[feature].value_counts().values, ax = position[index])
    position[index].set_title(f"bar chart for {feature}")
    
plt.tight_layout()

# %% [markdown]
# ### Bi-variate analysis

# %%
sns.countplot(data = categorical_df, x = "Education", hue = data["Default"])
# Out:
# <Axes: xlabel='Education', ylabel='count'>

# %%
fig, axes = plt.subplots(nrows= 4, ncols= 2, figsize = (20,20))

position = axes.flatten()

for index, feature in enumerate(cat_columns):
    sns.countplot(data = categorical_df, x = feature, hue = data["Default"], ax = position[index])
    position[index].set_title(f"Bar chart of {feature} and Default")

plt.tight_layout()

# %%
len(data)
# Out:
# 255347

# %%
data["Default"].value_counts().index
# Out:
# Index([0, 1], dtype='int64', name='Default')

# %%
data["Default"].value_counts().values
# Out:
# array([225694,  29653], dtype=int64)

# %%
sns.barplot(x = data["Default"].value_counts().index, y = data["Default"].value_counts().values)
# Out:
# <Axes: xlabel='Default'>

# %% [markdown]
# ### Data scaling should be done before data training
# #### data standardaization and data normalization

# %% [markdown]
# # Modelling (Loan Default Prediction)
# ### Data Pre-processing

# %%
# questions <==> features
# answers <==>labels/target

labels = data['Default']
features = data.drop(['Default'], axis=1)

# %%
labels
# Out:
# 0         0
# 1         0
# 2         1
# 3         0
# 4         0
#          ..
# 255342    0
# 255343    1
# 255344    0
# 255345    0
# 255346    0
# Name: Default, Length: 255347, dtype: int64

# %%
features.head()
# Out:
#    Age  Income  LoanAmount  CreditScore  MonthsEmployed  NumCreditLines  \
# 0   56   85994       50587          520              80               4
# 1   69   50432      124440          458              15               1
# 2   46   84208      129188          451              26               3
# 3   32   31713       44799          743               0               3
# 4   60   20437        9139          633               8               4
#
#    InterestRate  LoanTerm  DTIRatio    Education EmploymentType MaritalStatus  \
# 0         15.23        36      0.44   Bachelor's      Full-time      Divorced
# 1          4.81        60      0.68     Master's      Full-time       Married
# 2         21.17        24      0.31     Master's     Unemployed      Divorced
# 3          7.07        24      0.23  High School      Full-time       Married
# 4          6.51        48      0.73   Bachelor's     Unemployed      Divorced
#
#   HasMortgage HasDependents LoanPurpose HasCoSigner
# 0         Yes           Yes       Other         Yes
# 1          No            No       Other         Yes
# 2         Yes           Yes        Auto          No
# 3          No            No    Business          No
# 4          No           Yes        Auto          No

# %%
len(labels) == len(features)
# Out:
# True

# %% [markdown]
# ### Encoding categorical variables
# #### Using Label Encoding
# #### This means changing categorical data to numerical in a code format
# #### Eg let male = 1 and female = 2 etc.

# %%
# Select categorical columns
all_categorical_column = features.select_dtypes(include=['object'])

# %%
all_categorical_column.head()
# Out:
#      Education EmploymentType MaritalStatus HasMortgage HasDependents  \
# 0   Bachelor's      Full-time      Divorced         Yes           Yes
# 1     Master's      Full-time       Married          No            No
# 2     Master's     Unemployed      Divorced         Yes           Yes
# 3  High School      Full-time       Married          No            No
# 4   Bachelor's     Unemployed      Divorced          No           Yes
#
#   LoanPurpose HasCoSigner
# 0       Other         Yes
# 1       Other         Yes
# 2        Auto          No
# 3    Business          No
# 4        Auto          No

# %%
# Encoding categorical variables
# import Scikit library for machine learning
from sklearn.preprocessing import LabelEncoder

# Initialize the encoder
encoder = LabelEncoder()

# %% [markdown]
# Two steps to encode any data:
# 1. fit
# 2. transform

# %%
# Step 1 
encoder.fit(all_categorical_column['Education'])
# Out:
# LabelEncoder()

# %%
# Step 2
encoder.transform(all_categorical_column['Education'])
# Out:
# array([0, 2, 2, ..., 1, 1, 0])

# %%
# Combining both steps together in one function
encoder.fit_transform(all_categorical_column['Education'])
# Out:
# array([0, 2, 2, ..., 1, 1, 0])

# %% [markdown]
# #### Encoding all the categorical columns in a loop

# %%
for categorical_column in all_categorical_column:
    print(categorical_column)
# Out:
# Education
# EmploymentType
# MaritalStatus
# HasMortgage
# HasDependents
# LoanPurpose
# HasCoSigner

# %%
for categorical_column in all_categorical_column:
    features[categorical_column] = encoder.fit_transform(features[categorical_column])

# %%
features.head()
# Out:
#    Age  Income  LoanAmount  CreditScore  MonthsEmployed  NumCreditLines  \
# 0   56   85994       50587          520              80               4
# 1   69   50432      124440          458              15               1
# 2   46   84208      129188          451              26               3
# 3   32   31713       44799          743               0               3
# 4   60   20437        9139          633               8               4
#
#    InterestRate  LoanTerm  DTIRatio  Education  EmploymentType  MaritalStatus  \
# 0         15.23        36      0.44          0               0              0
# 1          4.81        60      0.68          2               0              1
# 2         21.17        24      0.31          2               3              0
# 3          7.07        24      0.23          1               0              1
# 4          6.51        48      0.73          0               3              0
#
#    HasMortgage  HasDependents  LoanPurpose  HasCoSigner
# 0            1              1            4            1
# 1            0              0            4            1
# 2            1              1            0            0
# 3            0              0            1            0
# 4            0              1            0            0

# %% [markdown]
# ### Data splitting and Feature scaling

# %%
print(f"Our data contains {len(features)} records before spliting")
# Out:
# Our data contains 255347 records before spliting

# %% [markdown]
# ### Split the data into training and testing sets

# %%
from sklearn.model_selection import train_test_split
# features <==> X
# label <===> y
# X_train <==> train feature
# X_test<==> test feature 
# y_train <==> train labels
# y_test <==> test labels

# Assuming you have your features and labels stored in separate variables
# features: A 2D numpy array or pandas DataFrame containing the feature values
# labels: A 1D numpy array or pandas Series containing the target values

# Split the data into training and testing sets
# test_size=0.2 means 20% of the data will be used for testing
# random_state=42 ensures reproducibility of the results

X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)
# Split the data into training and testing sets
# test_size=0.2 means 20% of the data will be used for testing
# random_state=42 ensures reproducibility of the results

X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)

# %%
print(f"Our train data contains {len(X_train)} records after spliting")
# Out:
# Our train data contains 204277 records after spliting

# %%
print(f"Our test data contains {len(X_test)} records after spliting")
# Out:
# Our test data contains 51070 records after spliting

# %%
len(X_train) + len(X_test) == len(features)
# Out:
# True

# %%
X_train.head()
# Out:
#         Age  Income  LoanAmount  CreditScore  MonthsEmployed  NumCreditLines  \
# 137187   18  137576      209136          846              26               2
# 230334   47   57194        5970          748              30               2
# 19687    26   84328       95065          453               7               2
# 106509   53   49795      229582          533             107               3
# 242291   49  115450       22072          840               0               4
#
#         InterestRate  LoanTerm  DTIRatio  Education  EmploymentType  \
# 137187         10.47        60      0.81          1               2
# 230334         19.72        36      0.73          1               3
# 19687          24.25        12      0.45          2               2
# 106509         14.44        60      0.17          0               2
# 242291         24.48        12      0.11          0               1
#
#         MaritalStatus  HasMortgage  HasDependents  LoanPurpose  HasCoSigner
# 137187              2            1              0            1            0
# 230334              0            0              1            2            0
# 19687               1            0              0            4            1
# 106509              2            1              0            0            1
# 242291              2            0              1            2            1

# %% [markdown]
# ## Model training
# #### We'll start with a logistic regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
# Initialize the model
model = LogisticRegression(random_state=42)

# %%
# Train the model
model.fit(X_train, y_train)
# Out:
# c:\Users\User\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(random_state=42)

# %%
# Make predictions on the test set
predictions = model.predict(X_test)

# %%
predictions
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
y_test.values
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
len(predictions) == len(y_test)
# Out:
# True

# %% [markdown]
# ### Model Evaluation

# %%
from sklearn.metrics import classification_report, confusion_matrix

# Evaluate the model
report = classification_report(y_test, predictions, digits=5)
matrix = confusion_matrix(y_test, predictions)

# %%
# Display results
print("Classification Report:\n", report)
print("Confusion Matrix:\n", matrix)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0    0.88456   0.99998   0.93873     45170
#            1    0.83333   0.00085   0.00169      5900
#
#     accuracy                        0.88455     51070
#    macro avg    0.85894   0.50041   0.47021     51070
# weighted avg    0.87864   0.88455   0.83048     51070
#
# Confusion Matrix:
#  [[45169     1]
#  [ 5895     5]]

# %%
# precision class 0
45169 /(5895 + 45169)
# Out:
# 0.8845566348112173

# %%
# precision class 1
5 / (1 + 5)
# Out:
# 0.8333333333333334

# %%
# recall class 0
45169 / (45169+1)
# Out:
# 0.9999778614124419

# %%
# recall class 1
5 / (5+5895)
# Out:
# 0.000847457627118644

# %%
sns.heatmap(matrix, annot=True, fmt='g')
plt.ylabel('Predictions')
plt.xlabel('Actual Value')
# Out:
# Text(0.5, 23.52222222222222, 'Actual Value')

# %% [markdown]
# ### Now let's experiment, and see how to improve the model performance

# %% [markdown]
# #### Now lets show the importance of data scaling
# Because our data is has a uniform distribution, we'll use Min-Max Scaler.<br>
# If the distribution is normal, we'll use a Standard Scaler<br>
# Use RobustScaler when you are unsure whether the distribution is normal or uniform<br>

# %%
from sklearn.preprocessing import MinMaxScaler

# Scale our training data
scaler = MinMaxScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Initialize the model
model = LogisticRegression(random_state=42)

# %%
# Train the model
model.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(random_state=42)

# %%
# Make predictions on the test set
predictions = model.predict(X_test_scaled)

# %%
# Evaluate the model
report = classification_report(y_test, predictions)
matrix = confusion_matrix(y_test, predictions)

# %%
# Display results
print("Classification Report:\n", report)
print("Confusion Matrix:\n", matrix)
print("\n")
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     45170
#            1       0.62      0.03      0.06      5900
#
#     accuracy                           0.89     51070
#    macro avg       0.75      0.51      0.50     51070
# weighted avg       0.86      0.89      0.84     51070
#
# Confusion Matrix:
#  [[45058   112]
#  [ 5717   183]]

# %%
sns.heatmap(matrix, annot=True, fmt='.6g')
# Out:
# <Axes: >

# %% [markdown]
# We can see the improvements in the class `1` predictions and slightly in the overall accuracy, precision, recall

# %% [markdown]
# Clearly the class imbalance is affecting the model's performance

# %%
sns.countplot(x="Default", data=data, )
# Out:
# <Axes: xlabel='Default', ylabel='count'>

# %% [markdown]
# ### Can we do better ?
# #### Fine tuning the model to perform better by specifying certian parameters during the class initialization.
# Why don't we inform the model of our class imbalance and manually assign some class weight/importance to our weak class (class: `1`) ?

# %%
# Initialize the model
model = LogisticRegression(random_state=42, class_weight={0:1, 1:4}) # Assuming misclassifying class 1 is 4 times more costly 
# Train the model
model.fit(X_train_scaled, y_train)
# Make predictions on the test set
predictions = model.predict(X_test_scaled)
# Evaluate the model
report = classification_report(y_test, predictions)
matrix = confusion_matrix(y_test, predictions)

# Display results
print("Classification Report:\n", report)
sns.heatmap(matrix, annot=True, fmt='.6g')
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.87      0.90     45170
#            1       0.30      0.42      0.35      5900
#
#     accuracy                           0.82     51070
#    macro avg       0.61      0.65      0.63     51070
# weighted avg       0.85      0.82      0.83     51070
# <Axes: >

# %% [markdown]
# ### Is this the best we can achieve ? Why not try other classification models?

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import RandomForestClassifier


class_weights = {0: 1, 1: 4} 

# Initialize and train the models
classifiers = [[LogisticRegression(random_state=42, class_weight=class_weights), 'Logistic Regression'],
               [SGDClassifier(random_state=42, class_weight=class_weights), 'SGD Classifiers'],
               [DecisionTreeClassifier(random_state=42, class_weight=class_weights), 'Decision Tree'],
               [RandomForestClassifier(random_state=42, class_weight=class_weights), 'Random Forest'],
              ]

for classifier in classifiers:
    model_name = classifier[1]
    model = classifier[0]
    print(f"<-- {model_name} -->")
    model.fit(X_train_scaled, y_train)
    predictions = model.predict(X_test_scaled)
    report = classification_report(y_test, predictions)
    matrix = confusion_matrix(y_test, predictions)
    print("Classification Report:\n", report)
    sns.heatmap(matrix, annot=True, fmt='g')
    plt.show()
# Out:
# <-- Logistic Regression -->
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.87      0.90     45170
#            1       0.30      0.42      0.35      5900
#
#     accuracy                           0.82     51070
#    macro avg       0.61      0.65      0.63     51070
# weighted avg       0.85      0.82      0.83     51070
# <-- SGD Classifiers -->
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.84      0.88     45170
#            1       0.28      0.48      0.36      5900
#
#     accuracy                           0.80     51070
#    macro avg       0.60      0.66      0.62     51070
# weighted avg       0.85      0.80      0.82     51070
# <-- Decision Tree -->
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.89      0.89     45170
#            1       0.20      0.20      0.20      5900
#
#     accuracy                           0.81     51070
#    macro avg       0.55      0.55      0.55     51070
# weighted avg       0.81      0.81      0.81     51070
# <-- Random Forest -->
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     45170
#            1       0.64      0.03      0.06      5900
#
#     accuracy                           0.89     51070
#    macro avg       0.76      0.51      0.50     51070
# weighted avg       0.86      0.89      0.84     51070

# %% [markdown]
# ### Do we actually need all these features?
# #### Why don't we slim down the model size by selecting the most IMPORTANT features and train with them ?
#
# #### Feature Importance and Feature Selection

# %%
features.head(2)
# Out:
#    Age  Income  LoanAmount  CreditScore  MonthsEmployed  NumCreditLines  \
# 0   56   85994       50587          520              80               4
# 1   69   50432      124440          458              15               1
#
#    InterestRate  LoanTerm  DTIRatio  Education  EmploymentType  MaritalStatus  \
# 0         15.23        36      0.44          0               0              0
# 1          4.81        60      0.68          2               0              1
#
#    HasMortgage  HasDependents  LoanPurpose  HasCoSigner
# 0            1              1            4            1
# 1            0              0            4            1

# %%
classifiers[2][0]
# Out:
# DecisionTreeClassifier(class_weight={0: 1, 1: 4}, random_state=42)

# %% [markdown]
# #### Feature importance is only possible if you have previously trained the model, just like we did.
# #### We can now Use the .feature_importances_ function to identify the most important features.
# #### It works only on tree baised ML algorithms like : RandomForestClassifier() and DecisionTreeClassifier()

# %%
# Feature importance using Random Forest
importances = classifiers[2][0].feature_importances_
importances
# Out:
# array([0.11221571, 0.13892787, 0.1272474 , 0.10077027, 0.10203739,
#        0.02508608, 0.13890597, 0.03176121, 0.08714361, 0.02467853,
#        0.02667411, 0.01917951, 0.01263035, 0.01130258, 0.02995916,
#        0.01148027])

# %%
len(importances) == len(features.columns)
# Out:
# True

# %% [markdown]
# #### Create a DataFrame to contain all the column names and their corresponding feature importance

# %%
feature_names = features.columns
feature_importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': importances})
feature_importance_df
# Out:
#            Feature  Importance
# 0              Age    0.112216
# 1           Income    0.138928
# 2       LoanAmount    0.127247
# 3      CreditScore    0.100770
# 4   MonthsEmployed    0.102037
# 5   NumCreditLines    0.025086
# 6     InterestRate    0.138906
# 7         LoanTerm    0.031761
# 8         DTIRatio    0.087144
# 9        Education    0.024679
# 10  EmploymentType    0.026674
# 11   MaritalStatus    0.019180
# 12     HasMortgage    0.012630
# 13   HasDependents    0.011303
# 14     LoanPurpose    0.029959
# 15     HasCoSigner    0.011480

# %% [markdown]
# #### Sorting the DataFrame will be :

# %%
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)
feature_importance_df
# Out:
#            Feature  Importance
# 1           Income    0.138928
# 6     InterestRate    0.138906
# 2       LoanAmount    0.127247
# 0              Age    0.112216
# 4   MonthsEmployed    0.102037
# 3      CreditScore    0.100770
# 8         DTIRatio    0.087144
# 7         LoanTerm    0.031761
# 14     LoanPurpose    0.029959
# 10  EmploymentType    0.026674
# 5   NumCreditLines    0.025086
# 9        Education    0.024679
# 11   MaritalStatus    0.019180
# 12     HasMortgage    0.012630
# 15     HasCoSigner    0.011480
# 13   HasDependents    0.011303

# %%
plt.figure(figsize=(10, 7))

sns.barplot(x='Importance', y='Feature', data=feature_importance_df, color='lightblue')
# Out:
# <Axes: xlabel='Importance', ylabel='Feature'>

# %% [markdown]
# ### Let's select the top 5 features
# <b>TODO:</b> Experiment with other number of features e.g. 3, 4, 6, 7, etc.

# %%
selected_features = feature_importance_df[:5]
selected_features
# Out:
#           Feature  Importance
# 1          Income    0.138928
# 6    InterestRate    0.138906
# 2      LoanAmount    0.127247
# 0             Age    0.112216
# 4  MonthsEmployed    0.102037

# %%
X_train[selected_features['Feature'].values]
# Out:
#         Income  InterestRate  LoanAmount  Age  MonthsEmployed
# 137187  137576         10.47      209136   18              26
# 230334   57194         19.72        5970   47              30
# 19687    84328         24.25       95065   26               7
# 106509   49795         14.44      229582   53             107
# 242291  115450         24.48       22072   49               0
# ...        ...           ...         ...  ...             ...
# 119879  116623         23.44      161673   40              79
# 103694   62958          9.29      189499   67              77
# 131932   34372          9.72       59645   62              94
# 146867  146262          4.31      198454   44               7
# 121958   97844         23.14      188593   36               2
#
# [204277 rows x 5 columns]

# %%
Xtrain_top_five = X_train[selected_features['Feature'].values]
Xtest_top_five = X_test[selected_features['Feature'].values]

# %% [markdown]
# #### Scale the new top 5 again

# %%
scaler = MinMaxScaler()

X_train_top_five_scaled = scaler.fit_transform(Xtrain_top_five)
X_test_top_five_scaled = scaler.transform(Xtest_top_five)

# %%
for classifier in classifiers:
    print(f"<-- {classifier[1]} -->")
    model_name = classifier[1]
    model = classifier[0]
    model.fit(X_train_top_five_scaled, y_train)
    predictions = model.predict(X_test_top_five_scaled)
    report = classification_report(y_test, predictions)
    matrix = confusion_matrix(y_test, predictions)
    print("Classification Report:\n", report)
    sns.heatmap(matrix, annot=True, fmt='g')
    plt.show()
# Out:
# <-- Logistic Regression -->
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.88      0.90     45170
#            1       0.30      0.40      0.34      5900
#
#     accuracy                           0.82     51070
#    macro avg       0.61      0.64      0.62     51070
# weighted avg       0.85      0.82      0.83     51070
# <-- SGD Classifiers -->
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.88      0.90     45170
#            1       0.30      0.40      0.34      5900
#
#     accuracy                           0.82     51070
#    macro avg       0.61      0.64      0.62     51070
# weighted avg       0.85      0.82      0.83     51070
# <-- Decision Tree -->
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.89      0.89     45170
#            1       0.20      0.20      0.20      5900
#
#     accuracy                           0.81     51070
#    macro avg       0.55      0.55      0.55     51070
# weighted avg       0.81      0.81      0.81     51070
# <-- Random Forest -->
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.99      0.94     45170
#            1       0.52      0.05      0.10      5900
#
#     accuracy                           0.88     51070
#    macro avg       0.70      0.52      0.52     51070
# weighted avg       0.85      0.88      0.84     51070

# %% [markdown]
# ### How can I automate this process of selecting the best parameters to train my model ?

# %%
from sklearn.model_selection import GridSearchCV

# Hyperparameter tuning for Decision Tree
param_grid = {
    'max_depth': [None, 20, 30, 50],
    'min_samples_split': [ 5, 7, 10],
    'class_weight': [{0:1, 1:2}, {0:1, 1:3}, {0:1, 1:4}]
}

grid_search = GridSearchCV(estimator=classifiers[2][0], param_grid=param_grid, cv=5, scoring="recall")
grid_search.fit(X_train_scaled, y_train)

print(f'Best Parameters: {grid_search.best_params_}')
print(f'Best Score: {grid_search.best_score_:.2f}')
# Out:
# Best Parameters: {'class_weight': {0: 1, 1: 4}, 'max_depth': 20, 'min_samples_split': 10}
# Best Score: 0.31

# %%
grid_search.best_estimator_
# Out:
# DecisionTreeClassifier(class_weight={0: 1, 1: 4}, max_depth=20,
#                        min_samples_split=10, random_state=42)

# %%
# Evaluate the best model
best_model = grid_search.best_estimator_
predictions = best_model.predict(X_test_scaled)

report = classification_report(y_test, predictions)
matrix = confusion_matrix(y_test, predictions)

# Display results
print("### Best Decision Tree Model ###")
print("Classification Report:\n", report)
sns.heatmap(matrix, annot=True, fmt='g')
plt.show()
# Out:
# ### Best Decision Tree Model ###
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.83      0.86     45170
#            1       0.19      0.31      0.24      5900
#
#     accuracy                           0.77     51070
#    macro avg       0.55      0.57      0.55     51070
# weighted avg       0.82      0.77      0.79     51070
